# %% [markdown]
# # PERTURBATION

# %%
from LingerGRN.perturb import *
# insilico pertubation
outdir='/home/kl467102/thesis/results/LINGER_output/' #output dir
Datadir = '/home/kl467102/proj_v0/downloads/' # Directory for the downloaded general gene regulatory network for LINGER
GRNdir=Datadir+'data_bulk/'
Input_dir= '/home/kl467102/proj_v0/'# input data dir
chrall,data_merge,Exp,Opn,Target,idx,TFname=load_data_ptb(Input_dir,outdir,GRNdir)
original=get_simulation(outdir,chrall,data_merge,GRNdir,Exp,Opn,Target,idx)
original.to_csv(outdir+'original.txt',sep='\t')
original

# %%
import importlib
import LingerGRN
importlib.reload(LingerGRN.perturb)
# Out:
# <module 'LingerGRN.perturb' from '/home/kl467102/miniconda3/envs/linger_enviroment/lib/python3.10/site-packages/LingerGRN/perturb.py'>

# %%
chrall,data_merge,Exp,Opn,Target,idx,TFname=load_data_ptb(Input_dir,outdir,GRNdir)

# %%
data_merge
# Out:
#         Symbol   id_s   chr  id_b
# 0       SAMD11      1  chr1  1425
# 1        NOC2L      2  chr1  1041
# 2       KLHL17      3  chr1   823
# 3      PLEKHN1      4  chr1  1215
# 4         HES4      5  chr1   681
# ...        ...    ...   ...   ...
# 14902    CLIC2  14903  chrX   102
# 14903    TMLHE  14904  chrX   636
# 14904    SPRY3  14905  chrX   578
# 14905    VAMP7  14906  chrX   664
# 14906     IL9R  14907  chrX   296
#
# [14907 rows x 4 columns]

# %%
Target.shape
# Out:
# (14914, 11898)

# %%
ll = [chrall,data_merge,Exp,Opn,Target,idx,TFname]
for l in ll:
    print(l.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 ll = [chrall,data_merge,Exp,Opn,Target,idx,TFname]
#       2 for l in ll:
# ----> 3     print(l.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
ll = [chrall, data_merge, Exp, Opn, Target, idx, TFname]

for l in ll:
    if hasattr(l, "shape"):  # Check if the object has a .shape attribute
        print(l.shape)
    else:
        print(f"{type(l)} does not have a .shape attribute")
# Out:
# <class 'list'> does not have a .shape attribute
# (14907, 4)
# (451, 11898)
# (143887, 11898)
# (14914, 11898)
# (14907, 4)
# (451,)

# %%
data_merge
# Out:
#         Symbol   id_s   chr  id_b
# 0       SAMD11      1  chr1  1425
# 1        NOC2L      2  chr1  1041
# 2       KLHL17      3  chr1   823
# 3      PLEKHN1      4  chr1  1215
# 4         HES4      5  chr1   681
# ...        ...    ...   ...   ...
# 14902    CLIC2  14903  chrX   102
# 14903    TMLHE  14904  chrX   636
# 14904    SPRY3  14905  chrX   578
# 14905    VAMP7  14906  chrX   664
# 14906     IL9R  14907  chrX   296
#
# [14907 rows x 4 columns]

# %%
idx
# Out:
#              0                                                  1  \
# 0       SAMD11  5_6_8_8_9_9_9_11_12_15_15_16_16_16_17_17_18_19...
# 1        NOC2L  5_6_8_8_9_9_9_11_12_16_19_21_22_22_23_23_23_24...
# 2       KLHL17  5_6_8_8_9_9_9_11_12_16_19_21_21_22_22_22_23_23...
# 3      PLEKHN1  5_6_8_8_9_9_9_11_12_16_19_21_22_22_22_23_23_23...
# 4         HES4  5_6_8_8_9_9_9_11_12_16_19_21_22_23_29_29_29_29...
# ...        ...                                                ...
# 14902    CLIC2  143713_143714_143715_143716_143717_143718_1437...
# 14903    TMLHE  143804_143804_143805_143806_143806_143807_1438...
# 14904    SPRY3  143809_143809_143810_143810_143811_143812_1438...
# 14905    VAMP7  143811_143811_143812_143812_143813_143813_1438...
# 14906     IL9R  143818_143818_143819_143820_143820_143821_1438...
#
#                                                        2  \
# 0      0_1_2_3_4_5_6_7_8_9_10_11_12_13_14_15_16_17_18...
# ...

# %%
from LingerGRN.perturb import *
# insilico pertubation
outdir='/home/kl467102/proj_v0/output_base/' #output dir
Datadir = '/home/kl467102/proj_v0/downloads/' # Directory for the downloaded general gene regulatory network for LINGER
GRNdir=Datadir+'data_bulk/'
Input_dir= '/home/kl467102/proj_v0/'# input data dir
chrall,data_merge,Exp,Opn,Target,idx,TFname=load_data_ptb(Input_dir,outdir,GRNdir)
#original=get_simulation(outdir,chrall,data_merge,GRNdir,Exp,Opn,Target,idx)
#original.to_csv(outdir+'original.txt',sep='\t')
#original
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 7
#       5 GRNdir=Datadir+'data_bulk/'
#       6 Input_dir= '/home/kl467102/proj_v0/'# input data dir
# ----> 7 chrall,data_merge,Exp,Opn,Target,idx,TFname=load_data_ptb(Input_dir,outdir,GRNdir)
#       8 #original=get_simulation(outdir,chrall,data_merge,GRNdir,Exp,Opn,Target,idx)
#       9 #original.to_csv(outdir+'original.txt',sep='\t')
#      10 #original
#
# File ~/miniconda3/envs/linger_enviroment/lib/python3.10/site-packages/LingerGRN/perturb.py:50, in load_data_ptb(Input_dir, outdir, GRNdir)
#      48 chrall=[str(i+1) for i in range(22)]
#      49 chrall.append('X')
# ---> 50 data_merge=pd.read_csv(outdir+'data_merge.txt',sep='\t',index_col=0)
#      51 return chrall,data_merge,Exp,Opn,Target,idx,TFname
#
# ...
